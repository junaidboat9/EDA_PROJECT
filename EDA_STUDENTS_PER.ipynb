# %% [markdown]
# **Student Performance**
# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
#
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#reading the data with the help of pandas
df=pd.read_csv("student-por.csv")

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
#to know the shape of the data
df.shape
# Out:
# (649, 33)

# %%
#to know the columns of the data
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
#to know the infor,ation of the datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
#after these we will check if there is any null value present in the data set
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# here we dont see any null value present in any of the columns

# %%
df['school'].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="school",data=df,palette="pastel")
plt.title("distribution of school")
plt.xlabel("school")
plt.ylabel("count")
plt.show()

# %% [markdown]
# here we get know the gp has larger number of student

# %%
sns.histplot(df['age'],bins=10,kde=True)
plt.title("distribution of age")
plt.xlabel("age")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# most common group here is 15-16 age group
# right skewed data

# %%
df['address'].unique()#we will checked the unique value of the column
# Out:
# array(['U', 'R'], dtype=object)

# %%
#we will plot the graph
plt.figure(figsize=(10,5))
sns.countplot(x="address",data=df,palette="dark")
plt.title("distribution of adress")
plt.xlabel("adress")
plt.ylabel("count")
plt.show()

# %% [markdown]
# here we saw the distribution of the adress in the graph
# using count plot were the most of the student live in the urban area and few student live in rural area

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_value=df.reason.value_counts()

# %%
explode=[0]*len(reason_value)
plt.pie(reason_value,labels=reason_value.index,autopct="%1.1f%%",explode=explode)
plt.title("Distribution of reasons for choosing the school")
plt.show()

# %% [markdown]
# here we made pie chart for a reason column and find that common is course

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['activities'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
a=df['activities'].value_counts()

# %%
plt.pie(a,labels=a.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7c90302857f0>,
# ...
#  [Text(-0.050567145149912965, 1.0988370961299896, 'no'),
#   Text(0.050567503196483114, -1.0988370796530638, 'yes')],
#  [Text(-0.027582079172679796, 0.5993656887981761, '51.5%'),
#   Text(0.02758227447080897, -0.599365679810762, '48.5%')])

# %% [markdown]
# here we made the pie chart for the activity column and we get to know that 48% of the student have been participated and 51% student had not participated in the activivty

# %%
df.Walc.unique()
# Out:
# array([1, 3, 2, 4, 5])

# %%
df.Walc.value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %% [markdown]
# 45 students daily consume alchol the consumption of alchol for 5 days is 45

# %%
df.Dalc.value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %% [markdown]
# 17 students daily consume alchohol

# %%
#biwariate analysis
plt.figure(figsize = (12, 6))


plt.subplot(1, 2, 1)
sns.countplot(x = 'Medu', data = df, palette = 'Set2')
plt.xlabel('Mother ed level')
plt.ylabel('count')
plt.title('Mother education level dist')



plt.subplot(1, 2, 2)
sns.countplot(x = 'Fedu', data = df, palette = 'Set3')
plt.xlabel('Father ed level')
plt.ylabel('count')
plt.title('Father education level dist')
# Out:
# Text(0.5, 1.0, 'Father education level dist')

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.barplot(x = 'studytime', y = 'G3', data=df)
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot(x='internet',y='G3',data=df)
# Out:
# <Axes: xlabel='internet', ylabel='G3'>

# %%
#multivariate
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data=df, palette = 'Set2')
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
num_cols = ['age', 'traveltime', 'studytime', 'absences', 'G1', 'G2', 'G3']


sns.boxplot(data = df[num_cols], palette = 'Set2')
# Out:
# <Axes: >

# %%
corr=df.corr(numeric_only =True)
plt.figure(figsize = (12, 10))
sns.heatmap(corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %% [markdown]
# bright color strong possitive correlation
# dark color strong negative correlation

# %%
students_grades_df = df.copy()
students_grades_df = students_grades_df.drop(['G1', 'G2', 'G3'], axis = 1)

# %%
def detect_outliers(columns):
    outlier_indices = []
    for column in columns:
        Q1=students_grades_df[column].quantile(0.25)
        Q3=students_grades_df[column].quantile(0.75)
        IQR = Q3-Q1

        #mask is boolean condition
        mask = (students_grades_df[column] >= (Q1-1.5)*IQR) & (students_grades_df[column] <= (Q1+1.5)*IQR)

        mask = mask.to_numpy() #bool value to numpy array

        #find the indices of values that do not satisfy the mask condition >> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
    return np.unique(np.concatenate(outlier_indices).ravel())

# %%
num_cols = ['age', 'absences']
outlier_indices = detect_outliers(num_cols)

# %%
students_grades_df

# %%
students_grades_df.columns

# %%
X,y= students_grades_df.iloc[:, :-1], students_grades_df.iloc[:, -1]

# %%
X
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
y
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (486, 29)

# %%
X_test.shape
# Out:
# (163, 29)

# %%
X_test
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 440     MS   M   16       U     GT3       T     1     1   at_home  services
# 242     GP   M   18       U     LE3       T     2     1   at_home     other
# 465     MS   F   18       U     GT3       T     1     2     other     other
# 347     GP   F   17       R     GT3       T     4     4  services  services
# 474     MS   M   15       R     LE3       T     1     3   at_home     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 592     MS   F   17       U     GT3       T     3     3  services  services
# 585     MS   F   17       R     LE3       A     3     1     other   at_home
# 494     MS   F   16       R     LE3       T     1     2   at_home     other
# 304     GP   F   18       U     GT3       T     2     2   at_home  services
# 165     GP   F   15       R     GT3       T     3     3  services  services
#
# ...
